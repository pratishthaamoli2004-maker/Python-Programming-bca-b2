# %% [markdown]
# ### **1) Write a Python function to find the maximum and minimum numbers from a sequence of numbers. (Note: Do not use built-in functions.)**

# %%
def find_max_min(nums):
    maximum = minimum = nums[0]
    for n in nums:
        if n > maximum: maximum = n
        if n < minimum: minimum = n
    return maximum, minimum

print(find_max_min([4, 2, 9, 1, 5]))
# Out:
# (9, 1)

# %% [markdown]
# ### **2) Write a Python function that takes a positive integer and returns the sum of the cube of all the positive integers smaller than the specified number.**

# %%
def sum_of_cubes(n):
    total = 0
    for i in range(1, n):
        total += i**3
    return total

print(sum_of_cubes(5))
# Out:
# 100

# %% [markdown]
# ### **3) Write a Python function to print 1 to n using recursion. (Note: Do not use loop)**

# %%
def print_n(n):
    if n == 0: return
    print_n(n-1)
    print(n, end=" ")

print_n(5)
# Out:
# 1 2 3 4 5

# %% [markdown]
# ### **4) Write a recursive function to print Fibonacci series upto n terms.**

# %%
def fib(n):
    if n <= 1: return n
    return fib(n-1) + fib(n-2)

def print_fib(n):
    for i in range(n):
        print(fib(i), end=" ")

print_fib(6)
# Out:
# 0 1 1 2 3 5

# %% [markdown]
# ### **5) Write a lambda function to find volume of cone.**

# %%
import math
volume = lambda r, h: (1/3) * math.pi * r*r * h
print(round(volume(3, 5), 2))
# Out:
# 47.12

# %% [markdown]
# ### **6) Write a lambda function which gives tuple of max and min from a list.**
#
# **Sample input: [10, 6, 8, 90, 12, 56]**
#
# **Sample output: (90,6)**

# %%
nums = [10, 6, 8, 90, 12, 56]
max_min = lambda x: (max(x), min(x))
print(max_min(nums))
# Out:
# (90, 6)

# %% [markdown]
# ### **7) Write functions to explain mentioned concepts:**
#
#
#
# **a. Keyword argument**
#
# **b. Default argument**
#
# **c. Variable length argument**
#
# **Make code of 6 lines and also give its output**

# %% [markdown]
# ### **a.**

# %%
def greet(name, age):
    print("Name:", name, "Age:", age)

greet(age=20, name="Riya")
# Out:
# Name: Riya Age: 20

# %% [markdown]
# ### **b.**

# %%
def greet(name="Guest"):
    print("Hello", name)

greet()
greet("Aman")
# Out:
# Hello Guest
# Hello Aman

# %% [markdown]
# ### **c.**

# %%
def add(*numbers):
    total = 0
    for n in numbers: total += n
    print(total)

add(2, 3, 4)
# Out:
# 9
