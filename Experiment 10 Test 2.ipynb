# %% [markdown]
# ### **Q1)  Class Variable vs Instance Variable**

# %%
class student:
    school_name = "UPES"
    def __init__(self, name, age) :
self.name = name
self.age = age

s1 = Student("Aman", 20)
s2 = Student("Pihu", 18)

print("School:", s1.school_name)
print("School:", s2.school_name)

print("Student 1:", s1.name, s1.age)
print("Student 2:", s2.name, s2.age)
# Out:
#   Cell In[41], line 4
#     self.name = name
#                     ^
# IndentationError: expected an indented block after function definition on line 3

# %% [markdown]
# ### **Q2) Instance Method and Class Method**

# %%
class Employee:
    company = "ABC LTD"
    
    def __init__(self,name, salary):
        self.name = name
        self.salary = salary
        
def show_details(self):
        print("Name:", self.name, "| salary:", self.salary, "| company:", Employee.company)
        
classmethod
def change_company(cls, new_name):
        cls.company = new_name
        
e1 = Employee("Pihu:", 10000)
e2 = Employee("Pooja:", 8000)
    
print("efore change :")
e1.show_details()
e2.show_details()
    
Employee.change_company("XYZ Ltd")
print("after change:")
e1.show_details()
e2.show_details()
# Out:
# efore change :
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 19
#      16 e2 = Employee("Pooja:", 8000)
#      18 print("efore change :")
# ---> 19 e1.show_details()
#      20 e2.show_details()
#      22 Employee.change_company("XYZ Ltd")
#
# AttributeError: 'Employee' object has no attribute 'show_details'

# %% [markdown]
# ### **Q3) Static Method**

# %%
class Mathhelper:
    @staticmethod
    def is_even(num):
        return num % 2 == 0

# %% [markdown]
# ### **Q4) Public and Private Data Members**

# %% [markdown]
# ### **Q5) Built-in Class Attributes**

# %%
class Student:
    """This is a Student class"""
print(Student.__name__)
print(Student.__doc__)
print(Student.__module__)
print(Student.__dict__)
# Out:
# Student
# This is a Student class
# __main__
# {'__module__': '__main__', '__firstlineno__': 1, '__doc__': 'This is a Student class', '__static_attributes__': (), '__dict__': <attribute '__dict__' of 'Student' objects>, '__weakref__': <attribute '__weakref__' of 'Student' objects>}

# %% [markdown]
# ### **Q6) Magic Methods / Operator Overloading**

# %%
class Product:

    def _init_(self, name, price):
        self.name = name
        self.price = price

    def _str_(self):
        return f"Product: {self.name}, Price: {self.price}"

    def _add_(self, other):
        return self.price + other.price

    def _eq_(self, other):
        return self.price == other.price

p1 = Product("Laptop", 50000)
p2 = Product("Phone", 30000)
p3 = Product("Tablet", 50000)

print(p1)
print(p1 + p2)
print(p1 == p3)
print(p1 == p2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 16
#      13     def _eq_(self, other):
#      14         return self.price == other.price
# ---> 16 p1 = Product("Laptop", 50000)
#      17 p2 = Product("Phone", 30000)
#      18 p3 = Product("Tablet", 50000)
#
# TypeError: Product() takes no arguments
